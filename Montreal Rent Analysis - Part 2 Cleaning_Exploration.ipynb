# %%
#import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import pearsonr, chi2_contingency
import re
import requests

# %% [markdown]
# # Cleaning Kijiji Data

# %%
# import csv file
df = pd.read_csv('unclean_kijiji_data.csv')

# %%
# Look at all the rows of the dataframe
display(df)
# Out:
#              ad_id   price             utility_flag  \
# 0     1.654805e+09  $1,850   All Utilities Included
# 1     1.674524e+09  $1,595  Some Utilities Included
# 2     1.631765e+09  $2,195  Some Utilities Included
# 3     1.683227e+09  $1,650  Some Utilities Included
# 4     1.675833e+09  $2,850  Some Utilities Included
# ...            ...     ...                      ...
# 3107  1.677837e+09  $2,099  Some Utilities Included
# 3108  1.682723e+09  $2,300    No Utilities Included
# 3109  1.682723e+09  $2,300    No Utilities Included
# 3110  1.682700e+09  $1,500    No Utilities Included
# 3111  1.677789e+09  $1,495    No Utilities Included
#
#                                                 address  unit_type Bedrooms  \
# 0       170 boul Rene Levesque E, Montreal, QC, H2X 1N6      Condo        1
# 1                2250 Guy street, Montréal, QC, H3H 2M3  Apartment        1
# 2              3450 Rue Drummond, Montréal, QC, H3G 1Y2  Apartment        1
# 3            390 Boul.Cote Vertu, Montréal, QC, H4N 1E3  Apartment        2
# 4     4840 Chemin de la Cote Saint Luc, Montreal, QC...  Apartment        3
# ...                                                 ...        ...      ...
# 3107  4858 chemin de la Côte-des-Neiges, Montréal, Q...  Apartment        2
# 3108             388 avenue Dorval, Dorval, QC, H9S 1L8      Condo        3
# 3109             388 avenue Dorval, Dorval, QC, H9S 1L8      Condo        2
# 3110                     8784, Sorel-Tracy, QC, J3R 0A2  Apartment        2
# 3111    11140 Rue Dorchester, Montréal-Est, QC, H1B 1Z5  Apartment        1
#
#       Bathrooms Utilities Included Wi-Fi and More  \
# 0           1.0                 []             []
# 1           1.0                 []             []
# 2           1.0                 []             []
# 3           1.0                 []             []
# 4           2.0                 []             []
# ...         ...                ...            ...
# 3107        2.0                 []             []
# 3108        2.0                 []             []
# 3109        1.0                 []             []
# 3110        1.0                 []   ['Internet']
# 3111        1.0                 []   ['Internet']
#
#                                              Appliances  ...  \
# 0     ['Laundry (In Unit)', 'Dishwasher', 'Fridge / ...  ...
# 1         ['Laundry (In Building)', 'Fridge / Freezer']  ...
# 2     ['Laundry (In Building)', 'Dishwasher', 'Fridg...  ...
# 3         ['Laundry (In Building)', 'Fridge / Freezer']  ...
# 4     ['Laundry (In Unit)', 'Laundry (In Building)',...  ...
# ...                                                 ...  ...
# 3107  ['Laundry (In Unit)', 'Dishwasher', 'Fridge / ...  ...
# 3108  ['Laundry (In Unit)', 'Dishwasher', 'Fridge / ...  ...
# 3109  ['Laundry (In Unit)', 'Dishwasher', 'Fridge / ...  ...
# 3110                                                 []  ...
# 3111                                     ['Dishwasher']  ...
#
#           Move-In Date Pet Friendly    Size (sqft) Furnished Air Conditioning  \
# 0        March 1, 2024          Yes  Not Available        No              Yes
# 1                  NaN           No          1,190        No               No
# 2     November 1, 2023           No            955        No              Yes
# 3          May 1, 2024           No  Not Available        No               No
# 4        April 1, 2024           No          1,500        No              Yes
# ...                ...          ...            ...       ...              ...
# 3107               NaN      Limited            963        No               No
# 3108      July 1, 2024          Yes  Not Available        No              Yes
# 3109      July 1, 2024          Yes  Not Available        No              Yes
# 3110  February 1, 2024          Yes          1,080        No              Yes
# 3111               NaN           No            911        No              Yes
#
#      Smoking Permitted Barrier-free Entrances and Ramps Visual Aids  \
# 0                   No                              Yes          No
# 1                   No                              NaN         NaN
# 2                   No                              Yes          No
# 3                   No                              NaN         NaN
# 4                   No                               No          No
# ...                ...                              ...         ...
# 3107     Outdoors only                              Yes          No
# 3108                No                              NaN         NaN
# 3109                No                              NaN         NaN
# 3110                No                              NaN         NaN
# 3111                No                              NaN         NaN
#
#      Accessible Washrooms in Suite  \
# 0                               No
# 1                              NaN
# 2                               No
# 3                              NaN
# 4                               No
# ...                            ...
# 3107                            No
# 3108                           NaN
# 3109                           NaN
# 3110                           NaN
# 3111                           NaN
#
#                                                  ad_url
# 0     https://www.kijiji.ca/v-apartments-condos/vill...
# 1     https://www.kijiji.ca/v-apartments-condos/vill...
# 2     https://www.kijiji.ca/v-apartments-condos/vill...
# 3     https://www.kijiji.ca/v-apartments-condos/vill...
# 4     https://www.kijiji.ca/v-apartments-condos/vill...
# ...                                                 ...
# 3107  https://www.kijiji.ca/v-apartments-condos/vill...
# 3108  https://www.kijiji.ca/v-apartments-condos/vill...
# 3109  https://www.kijiji.ca/v-apartments-condos/vill...
# 3110  https://www.kijiji.ca/v-apartments-condos/long...
# 3111  https://www.kijiji.ca/v-apartments-condos/vill...
#
# [3112 rows x 25 columns]

# %%
# Get a concise summary of the dataframe
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3112 entries, 0 to 3111
# Data columns (total 25 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   ad_id                             3099 non-null   float64
#  1   price                             3085 non-null   object
#  2   utility_flag                      3083 non-null   object
#  3   address                           3085 non-null   object
#  4   unit_type                         3083 non-null   object
#  5   Bedrooms                          3083 non-null   object
#  6   Bathrooms                         3083 non-null   float64
#  7   Utilities Included                3083 non-null   object
#  8   Wi-Fi and More                    3083 non-null   object
#  9   Appliances                        3083 non-null   object
#  10  Personal Outdoor Space            3083 non-null   object
#  11  Amenities                         2767 non-null   object
#  12  Elevator Accessibility Features   408 non-null    object
#  13  Parking Included                  3083 non-null   object
#  14  Agreement Type                    3083 non-null   object
#  15  Move-In Date                      2562 non-null   object
#  16  Pet Friendly                      3083 non-null   object
#  17  Size (sqft)                       3083 non-null   object
#  18  Furnished                         3083 non-null   object
#  19  Air Conditioning                  3083 non-null   object
#  20  Smoking Permitted                 3083 non-null   object
#  21  Barrier-free Entrances and Ramps  463 non-null    object
#  22  Visual Aids                       463 non-null    object
#  23  Accessible Washrooms in Suite     463 non-null    object
#  24  ad_url                            3112 non-null   object
# dtypes: float64(2), object(23)
# memory usage: 607.9+ KB
# None

# %%
# Length of the dataframe
print(len(df.ad_url))
# Out:
# 3112

# %%
# Detecting duplicates ad_id
duplicates_id = df[df.duplicated(subset=['ad_id'], keep=False)]
duplicates_id = duplicates_id.sort_values(by='ad_id', ascending=True)
duplicates_id
# Out:
#              ad_id   price            utility_flag  \
# 165   1.394103e+09    $950  All Utilities Included
# 513   1.394103e+09    $950  All Utilities Included
# 89    1.505786e+09  $2,195  All Utilities Included
# 437   1.505786e+09  $2,195  All Utilities Included
# 88    1.505786e+09  $2,145  All Utilities Included
# ...            ...     ...                     ...
# 1796           NaN     NaN                     NaN
# 1972           NaN     NaN                     NaN
# 2356           NaN     NaN                     NaN
# 2615           NaN     NaN                     NaN
# 2738           NaN     NaN                     NaN
#
#                                         address  unit_type Bedrooms  \
# 165          Av. Papineau, Montréal, QC, Canada  Apartment        1
# 513          Av. Papineau, Montréal, QC, Canada  Apartment        1
# 89    1180 rue du Sussex, Montréal, QC, H3H 0B5  Apartment        1
# 437   1180 rue du Sussex, Montréal, QC, H3H 0B5  Apartment        1
# 88    1180 rue du Sussex, Montréal, QC, H3H 0B5  Apartment        1
# ...                                         ...        ...      ...
# 1796                                        NaN        NaN      NaN
# 1972                                        NaN        NaN      NaN
# 2356                                        NaN        NaN      NaN
# 2615                                        NaN        NaN      NaN
# 2738                                        NaN        NaN      NaN
#
#       Bathrooms Utilities Included Wi-Fi and More  \
# 165         1.0                 []             []
# 513         1.0                 []             []
# 89          1.0                 []   ['Internet']
# 437         1.0                 []   ['Internet']
# 88          1.0                 []   ['Internet']
# ...         ...                ...            ...
# 1796        NaN                NaN            NaN
# 1972        NaN                NaN            NaN
# 2356        NaN                NaN            NaN
# 2615        NaN                NaN            NaN
# 2738        NaN                NaN            NaN
#
#                                              Appliances  ...   Move-In Date  \
# 165                           ['Laundry (In Building)']  ...  March 1, 2024
# 513                           ['Laundry (In Building)']  ...  March 1, 2024
# 89    ['Laundry (In Unit)', 'Dishwasher', 'Fridge / ...  ...            NaN
# 437   ['Laundry (In Unit)', 'Dishwasher', 'Fridge / ...  ...            NaN
# 88    ['Laundry (In Unit)', 'Dishwasher', 'Fridge / ...  ...            NaN
# ...                                                 ...  ...            ...
# 1796                                                NaN  ...            NaN
# 1972                                                NaN  ...            NaN
# 2356                                                NaN  ...            NaN
# 2615                                                NaN  ...            NaN
# 2738                                                NaN  ...            NaN
#
#      Pet Friendly Size (sqft) Furnished Air Conditioning Smoking Permitted  \
# 165            No           1       Yes               No                No
# 513            No           1       Yes               No                No
# 89            Yes         646        No              Yes                No
# 437           Yes         646        No              Yes                No
# 88            Yes         619        No              Yes                No
# ...           ...         ...       ...              ...               ...
# 1796          NaN         NaN       NaN              NaN               NaN
# 1972          NaN         NaN       NaN              NaN               NaN
# 2356          NaN         NaN       NaN              NaN               NaN
# 2615          NaN         NaN       NaN              NaN               NaN
# 2738          NaN         NaN       NaN              NaN               NaN
#
#      Barrier-free Entrances and Ramps Visual Aids  \
# 165                               Yes          No
# 513                               Yes          No
# 89                                NaN         NaN
# 437                               NaN         NaN
# 88                                NaN         NaN
# ...                               ...         ...
# 1796                              NaN         NaN
# 1972                              NaN         NaN
# 2356                              NaN         NaN
# 2615                              NaN         NaN
# 2738                              NaN         NaN
#
#      Accessible Washrooms in Suite  \
# 165                             No
# 513                             No
# 89                             NaN
# 437                            NaN
# 88                             NaN
# ...                            ...
# 1796                           NaN
# 1972                           NaN
# 2356                           NaN
# 2615                           NaN
# 2738                           NaN
#
#                                                  ad_url
# 165   https://www.kijiji.ca/v-apartments-condos/vill...
# 513   https://www.kijiji.ca/v-apartments-condos/vill...
# 89    https://www.kijiji.ca/v-apartments-condos/vill...
# 437   https://www.kijiji.ca/v-apartments-condos/vill...
# 88    https://www.kijiji.ca/v-apartments-condos/vill...
# ...                                                 ...
# 1796  https://www.kijiji.ca/v-apartments-condos/vill...
# 1972  https://www.kijiji.ca/v-apartments-condos/vill...
# 2356  https://www.kijiji.ca/v-apartments-condos/lava...
# 2615  https://www.kijiji.ca/v-apartments-condos/vill...
# 2738  https://www.kijiji.ca/v-apartments-condos/vill...
#
# [705 rows x 25 columns]

# %%
# Remove duplicates based on ad id
df = df.drop_duplicates(subset=['ad_id'])

# %%
# Detecting duplicates ad_url
duplicates_id = df[df.duplicated(subset=['ad_url'], keep=False)]
duplicates_id = duplicates_id.sort_values(by='ad_url', ascending=True)
duplicates_id
# Out:
#              ad_id   price             utility_flag  \
# 5     1.686718e+09  $1,600    No Utilities Included
# 1456  7.492642e+06     NaN                      NaN
# 817   1.686565e+09  $2,080    No Utilities Included
# 1431  1.685853e+09  $1,600    No Utilities Included
# 160   1.683273e+09  $2,095  Some Utilities Included
# 265   1.686830e+09     NaN                      NaN
# 42             NaN     NaN                      NaN
# 50    1.686849e+09  $1,570  Some Utilities Included
#
#                                   address  unit_type Bedrooms  Bathrooms  \
# 5        24 9e Avenue, Deux-Montagnes, QC  Apartment        2        1.0
# 1456                                  NaN        NaN      NaN        NaN
# 817              Boucherville, QC J4B 0C7      Condo        2        1.5
# 1431    Baroness Crescent, North York, ON   Basement        2        1.0
# 160   3555 Atwater, Montreal, QC, H3H 1Y3  Apartment        2        1.0
# 265                                   NaN        NaN      NaN        NaN
# 42                                    NaN        NaN      NaN        NaN
# 50                   Montréal, QC H2G 2X7  Apartment        2        1.0
#
#      Utilities Included Wi-Fi and More  \
# 5                    []   ['Internet']
# 1456                NaN            NaN
# 817                  []   ['Internet']
# 1431                 []             []
# 160                  []             []
# 265                 NaN            NaN
# 42                  NaN            NaN
# 50                   []   ['Internet']
#
#                                              Appliances  ...   Move-In Date  \
# 5     ['Laundry (In Unit)', 'Dishwasher', 'Fridge / ...  ...  April 1, 2024
# 1456                                                NaN  ...            NaN
# 817   ['Laundry (In Unit)', 'Dishwasher', 'Fridge / ...  ...  June 15, 2024
# 1431  ['Laundry (In Unit)', 'Dishwasher', 'Fridge / ...  ...  April 1, 2024
# 160   ['Laundry (In Building)', 'Dishwasher', 'Fridg...  ...   July 1, 2024
# 265                                                 NaN  ...            NaN
# 42                                                  NaN  ...            NaN
# 50                            ['Laundry (In Building)']  ...  April 1, 2024
#
#      Pet Friendly Size (sqft) Furnished Air Conditioning Smoking Permitted  \
# 5         Limited         962        No              Yes                No
# 1456          NaN         NaN       NaN              NaN               NaN
# 817       Limited       1,080       Yes              Yes     Outdoors only
# 1431           No         600       Yes              Yes                No
# 160            No       1,000        No               No                No
# 265           NaN         NaN       NaN              NaN               NaN
# 42            NaN         NaN       NaN              NaN               NaN
# 50             No         650       Yes               No                No
#
#      Barrier-free Entrances and Ramps Visual Aids  \
# 5                                 NaN         NaN
# 1456                              NaN         NaN
# 817                               NaN         NaN
# 1431                              NaN         NaN
# 160                               Yes          No
# 265                               NaN         NaN
# 42                                NaN         NaN
# 50                                NaN         NaN
#
#      Accessible Washrooms in Suite  \
# 5                              NaN
# 1456                           NaN
# 817                            NaN
# 1431                           NaN
# 160                             No
# 265                            NaN
# 42                             NaN
# 50                             NaN
#
#                                                  ad_url
# 5     https://www.kijiji.ca/v-apartments-condos/lava...
# 1456  https://www.kijiji.ca/v-apartments-condos/lava...
# 817   https://www.kijiji.ca/v-apartments-condos/long...
# 1431  https://www.kijiji.ca/v-apartments-condos/long...
# 160   https://www.kijiji.ca/v-apartments-condos/vill...
# 265   https://www.kijiji.ca/v-apartments-condos/vill...
# 42    https://www.kijiji.ca/v-apartments-condos/vill...
# 50    https://www.kijiji.ca/v-apartments-condos/vill...
#
# [8 rows x 25 columns]

# %% [markdown]
# Remove ad_url duplicate where multiple columns are empty

# %%
# Sort the DataFrame based on the 'price' column
df_sorted = df.sort_values(by='price', na_position='last')

# %%
# Drop duplicates considering only the 'ad_url' column and dropping rows where all other columns are None
df = df_sorted.drop_duplicates(subset='ad_url', keep='first', inplace=False)

# %%
# Remove rows where the price column is blank
df = df.dropna(subset=['price'], how='all')

# %%
print(df)
# Out:
#              ad_id           price             utility_flag  \
# 1090  1.686674e+09          $1,000    No Utilities Included
# 2002  1.686210e+09          $1,000    No Utilities Included
# 1904  1.686271e+09          $1,000    No Utilities Included
# 1869  1.686289e+09          $1,000    No Utilities Included
# 1827  1.686326e+09          $1,000    No Utilities Included
# ...            ...             ...                      ...
# 297   1.686803e+09  Please Contact  Some Utilities Included
# 2596  1.607354e+09  Please Contact    No Utilities Included
# 2710  1.685764e+09  Please Contact   All Utilities Included
# 1222  1.505825e+09  Please Contact    No Utilities Included
# 2537  1.685924e+09      Swap/Trade    No Utilities Included
#
#                                               address  unit_type  \
# 1090                  Pointe-aux-Trembles, QC H1A 1V9  Apartment
# 2002  775 Boul St-Luc, St-Jean-sur-Richelieu, J2W 2G6  Apartment
# 1904                             Montréal, QC H4E 3W3  Apartment
# 1869           2333 Rue Modigliani, Montréal, H4R 3J6  Apartment
# 1827                             Montréal, QC H2K 4B2  Apartment
# ...                                               ...        ...
# 297         Boulevard René-Lévesque Est, Montreal, QC      Condo
# 2596       6750 Avenue du Parc, Montréal, QC, H3N 1W7  Apartment
# 2710                                Anjou, QC H1K 1M9   Basement
# 1222        1009 Rue De Bleury, Montreal, QC, H2Z 0A3  Apartment
# 2537                             Montreal, QC H3H 1M2  Apartment
#
#              Bedrooms  Bathrooms Utilities Included  \
# 1090                2        1.0                 []
# 2002                1        1.5                 []
# 1904  Bachelor/Studio        1.0                 []
# 1869                2        1.0                 []
# 1827                3        1.0                 []
# ...               ...        ...                ...
# 297                 2        2.0                 []
# 2596  Bachelor/Studio        1.0                 []
# 2710                2        1.0                 []
# 1222                2        1.0                 []
# 2537                2        1.0                 []
#
#                   Wi-Fi and More  \
# 1090                          []
# 2002                          []
# 1904                          []
# 1869                          []
# 1827                          []
# ...                          ...
# 297                           []
# 2596                          []
# 2710  ['Cable / TV', 'Internet']
# 1222                          []
# 2537                          []
#
#                                              Appliances  ...  \
# 1090                                                 []  ...
# 2002                                                 []  ...
# 1904          ['Laundry (In Unit)', 'Fridge / Freezer']  ...
# 1869                                                 []  ...
# 1827          ['Laundry (In Unit)', 'Fridge / Freezer']  ...
# ...                                                 ...  ...
# 297   ['Laundry (In Unit)', 'Dishwasher', 'Fridge / ...  ...
# 2596                                                 []  ...
# 2710                              ['Laundry (In Unit)']  ...
# 1222  ['Laundry (In Unit)', 'Dishwasher', 'Fridge / ...  ...
# 2537      ['Laundry (In Building)', 'Fridge / Freezer']  ...
#
#            Move-In Date Pet Friendly    Size (sqft) Furnished  \
# 1090      June 30, 2024           No              1        No
# 2002      March 2, 2024          Yes          1,000        No
# 1904      March 1, 2024      Limited              1       Yes
# 1869    October 1, 2024           No              1        No
# 1827      April 1, 2024      Limited              1        No
# ...                 ...          ...            ...       ...
# 297       March 1, 2024           No            800        No
# 2596                NaN           No  Not Available        No
# 2710  February 22, 2024           No            227       Yes
# 1222     August 1, 2020          Yes          1,080        No
# 2537      April 1, 2024           No            450        No
#
#      Air Conditioning Smoking Permitted Barrier-free Entrances and Ramps  \
# 1090               No                No                              NaN
# 2002              Yes     Outdoors only                              NaN
# 1904               No                No                              NaN
# 1869               No                No                              NaN
# 1827               No     Outdoors only                              NaN
# ...               ...               ...                              ...
# 297               Yes                No                              Yes
# 2596               No                No                              NaN
# 2710              Yes     Outdoors only                              NaN
# 1222              Yes     Outdoors only                              Yes
# 2537               No     Outdoors only                              NaN
#
#      Visual Aids Accessible Washrooms in Suite  \
# 1090         NaN                           NaN
# 2002         NaN                           NaN
# 1904         NaN                           NaN
# 1869         NaN                           NaN
# 1827         NaN                           NaN
# ...          ...                           ...
# 297           No                            No
# 2596         NaN                           NaN
# 2710         NaN                           NaN
# 1222          No                            No
# 2537         NaN                           NaN
#
#                                                  ad_url
# 1090  https://www.kijiji.ca/v-apartments-condos/vill...
# 2002  https://www.kijiji.ca/v-apartments-condos/long...
# 1904  https://www.kijiji.ca/v-apartments-condos/vill...
# 1869  https://www.kijiji.ca/v-apartments-condos/vill...
# 1827  https://www.kijiji.ca/v-apartments-condos/vill...
# ...                                                 ...
# 297   https://www.kijiji.ca/v-apartments-condos/vill...
# 2596  https://www.kijiji.ca/v-apartments-condos/vill...
# 2710  https://www.kijiji.ca/v-apartments-condos/vill...
# 1222  https://www.kijiji.ca/v-apartments-condos/vill...
# 2537  https://www.kijiji.ca/v-apartments-condos/vill...
#
# [2738 rows x 25 columns]

# %%
# Display price columns without a numeric value
df_none_price = df[(df.price == 'Please Contact') | (df.price =='Swap/Trade')]

# Drop rows where price is equal to 'Please Contact' or 'Swap/Trade'
df = df[(df['price'] != 'Please Contact') & (df['price'] != 'Swap/Trade')]

# %% [markdown]
# Data column review and Conversion

# %%
# Convert column 'ad_id' from float to string
df.ad_id = df.ad_id.astype(str)

# %%
# Remove symbols from the price column using regex
df['price'] = df['price'].str.replace(r'[^\w\s]', '')
print(df['price'])
# Out:
# 1090    1000
# 2002    1000
# 1904    1000
# 1869    1000
# 1827    1000
#         ...
# 1311     995
# 1008     995
# 1379     995
# 138      995
# 2559     999
# Name: price, Length: 2668, dtype: object
# /var/folders/ds/djp1xt_s7tz0zm9zv957dll00000gn/T/ipykernel_32687/3202711946.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['price'] = df['price'].str.replace(r'[^\w\s]', '')

# %%
print(df.head(15))
# Out:
#              ad_id price             utility_flag  \
# 1090  1686673911.0  1000    No Utilities Included
# 2002  1686209958.0  1000    No Utilities Included
# 1904  1686271403.0  1000    No Utilities Included
# 1869  1686289201.0  1000    No Utilities Included
# 1827  1686326330.0  1000    No Utilities Included
# 1765  1686370997.0  1000  Some Utilities Included
# 62    1684189900.0  1000  Some Utilities Included
# 1636  1686459285.0  1000                      NaN
# 1588  1686506710.0  1000    No Utilities Included
# 2402  1686009276.0  1000    No Utilities Included
# 44    1686848160.0  1000    No Utilities Included
# 242   1554985109.0  1000  Some Utilities Included
# 1355  1686604124.0  1000    No Utilities Included
# 2396  1686012610.0  1000    No Utilities Included
# 178   1686182999.0  1000    No Utilities Included
#
#                                                address  unit_type  \
# 1090                   Pointe-aux-Trembles, QC H1A 1V9  Apartment
# 2002   775 Boul St-Luc, St-Jean-sur-Richelieu, J2W 2G6  Apartment
# 1904                              Montréal, QC H4E 3W3  Apartment
# 1869            2333 Rue Modigliani, Montréal, H4R 3J6  Apartment
# 1827                              Montréal, QC H2K 4B2  Apartment
# 1765                             Longueuil, QC, J3Y5H3      Condo
# 62                7280 Durocher, Montreal, QC, H3N 1Z9  Apartment
# 1636                  Rue Ontario E, Montréal, H2K 1X3        NaN
# 1588                  8503 Rue Hochelaga, Montréal, QC  Apartment
# 2402                              Montréal, QC H1L 1Z5  Apartment
# 44                                166 6e Av, Laval, QC  Apartment
# 242   Rue de Gentilly E, Longueuil, QC J4J 4L2, Canada  Apartment
# 1355       12100 Av l'Archevêque, Montréal, QC H1H 3C1  Apartment
# 2396                             Longueuil, QC J4J 2V7  Apartment
# 178         4327 rue de Brébeuf, Montréal, QC, H2J 3K6  Apartment
#
#              Bedrooms  Bathrooms Utilities Included Wi-Fi and More  \
# 1090                2        1.0                 []             []
# 2002                1        1.5                 []             []
# 1904  Bachelor/Studio        1.0                 []             []
# 1869                2        1.0                 []             []
# 1827                3        1.0                 []             []
# 1765                2        1.0                 []             []
# 62    Bachelor/Studio        1.0                 []   ['Internet']
# 1636              NaN        NaN                NaN            NaN
# 1588                2        1.0                 []             []
# 2402          2 + Den        1.0                 []             []
# 44            1 + Den        1.5                 []             []
# 242   Bachelor/Studio        1.0                 []             []
# 1355                1        1.0                 []             []
# 2396                2        1.0                 []             []
# 178   Bachelor/Studio        1.0                 []             []
#
#                                              Appliances  ...     Move-In Date  \
# 1090                                                 []  ...    June 30, 2024
# 2002                                                 []  ...    March 2, 2024
# 1904          ['Laundry (In Unit)', 'Fridge / Freezer']  ...    March 1, 2024
# 1869                                                 []  ...  October 1, 2024
# 1827          ['Laundry (In Unit)', 'Fridge / Freezer']  ...    April 1, 2024
# 1765                                                 []  ...     June 1, 2024
# 62        ['Laundry (In Building)', 'Fridge / Freezer']  ...              NaN
# 1636                                                NaN  ...              NaN
# 1588                                                 []  ...    April 1, 2024
# 2402                                                 []  ...     July 1, 2024
# 44                                ['Laundry (In Unit)']  ...    April 1, 2024
# 242   ['Laundry (In Unit)', 'Laundry (In Building)',...  ...    March 1, 2024
# 1355                                                 []  ...      May 1, 2024
# 2396                          ['Laundry (In Building)']  ...   August 1, 2024
# 178                                                  []  ...    March 1, 2024
#
#      Pet Friendly    Size (sqft) Furnished Air Conditioning Smoking Permitted  \
# 1090           No              1        No               No                No
# 2002          Yes          1,000        No              Yes     Outdoors only
# 1904      Limited              1       Yes               No                No
# 1869           No              1        No               No                No
# 1827      Limited              1        No               No     Outdoors only
# 1765      Limited            785        No               No                No
# 62             No  Not Available        No               No                No
# 1636          NaN            NaN       NaN              NaN               NaN
# 1588           No            800        No               No                No
# 2402           No            735        No               No                No
# 44        Limited            650        No               No               Yes
# 242           Yes            850        No               No               Yes
# 1355      Limited            550        No               No                No
# 2396           No            800        No               No     Outdoors only
# 178            No  Not Available        No               No                No
#
#      Barrier-free Entrances and Ramps Visual Aids  \
# 1090                              NaN         NaN
# 2002                              NaN         NaN
# 1904                              NaN         NaN
# 1869                              NaN         NaN
# 1827                              NaN         NaN
# 1765                              NaN         NaN
# 62                                NaN         NaN
# 1636                              NaN         NaN
# 1588                              NaN         NaN
# 2402                              NaN         NaN
# 44                                NaN         NaN
# 242                               NaN         NaN
# 1355                              NaN         NaN
# 2396                              NaN         NaN
# 178                               NaN         NaN
#
#      Accessible Washrooms in Suite  \
# 1090                           NaN
# 2002                           NaN
# 1904                           NaN
# 1869                           NaN
# 1827                           NaN
# 1765                           NaN
# 62                             NaN
# 1636                           NaN
# 1588                           NaN
# 2402                           NaN
# 44                             NaN
# 242                            NaN
# 1355                           NaN
# 2396                           NaN
# 178                            NaN
#
#                                                  ad_url
# 1090  https://www.kijiji.ca/v-apartments-condos/vill...
# 2002  https://www.kijiji.ca/v-apartments-condos/long...
# 1904  https://www.kijiji.ca/v-apartments-condos/vill...
# 1869  https://www.kijiji.ca/v-apartments-condos/vill...
# 1827  https://www.kijiji.ca/v-apartments-condos/vill...
# 1765  https://www.kijiji.ca/v-apartments-condos/long...
# 62    https://www.kijiji.ca/v-apartments-condos/vill...
# 1636  https://www.kijiji.ca/v-apartments-condos/vill...
# 1588  https://www.kijiji.ca/v-apartments-condos/vill...
# 2402  https://www.kijiji.ca/v-apartments-condos/vill...
# 44    https://www.kijiji.ca/v-apartments-condos/lava...
# 242   https://www.kijiji.ca/v-apartments-condos/long...
# 1355  https://www.kijiji.ca/v-apartments-condos/vill...
# 2396  https://www.kijiji.ca/v-apartments-condos/long...
# 178   https://www.kijiji.ca/v-apartments-condos/vill...
#
# [15 rows x 25 columns]

# %%
# Review utility_flag column where data is empty
df_uti_flag = df[df['utility_flag'].isna()]
print(df_uti_flag)
# Out:
#              ad_id price utility_flag                             address  \
# 1636  1686459285.0  1000          NaN    Rue Ontario E, Montréal, H2K 1X3
# 1809  1686333691.0  1775          NaN  553 Av Gonthier, Montréal, H1L 3V5
#
#      unit_type Bedrooms  Bathrooms Utilities Included Wi-Fi and More  \
# 1636       NaN      NaN        NaN                NaN            NaN
# 1809       NaN      NaN        NaN                NaN            NaN
#
#      Appliances  ... Move-In Date Pet Friendly Size (sqft) Furnished  \
# 1636        NaN  ...          NaN          NaN         NaN       NaN
# 1809        NaN  ...          NaN          NaN         NaN       NaN
#
#      Air Conditioning Smoking Permitted Barrier-free Entrances and Ramps  \
# 1636              NaN               NaN                              NaN
# 1809              NaN               NaN                              NaN
#
#      Visual Aids Accessible Washrooms in Suite  \
# 1636         NaN                           NaN
# 1809         NaN                           NaN
#
#                                                  ad_url
# 1636  https://www.kijiji.ca/v-apartments-condos/vill...
# 1809  https://www.kijiji.ca/v-apartments-condos/vill...
#
# [2 rows x 25 columns]

# %%
# Delete rows where utility_flag is empty
df = df.dropna(subset=['utility_flag'], how='all')

# Review unique values within the utility_flag column
df_utl_unique = df.utility_flag.unique()
print(df_utl_unique)
# Out:
# ['No Utilities Included' 'Some Utilities Included'
#  'All Utilities Included']

# %%
# Review unique values within the utility_flag column
df_utl_unique = df.utility_flag.unique()
print(df_utl_unique)
# Out:
# ['No Utilities Included' 'Some Utilities Included'
#  'All Utilities Included']

# %%
def extract_street_name(address):
    match = re.search(r'^\s*(\d*\s*\w*),\s*[A-Z]{2}\s*\b', address, flags=re.IGNORECASE)
    if match:
        return match.group(1).strip()
    else:
        return None

df['street_name'] = df['address'].apply(extract_street_name)

# %%
# Extracting street name, city, province, and postal code
df['city'] = df['address'].apply(lambda x: re.search(r'^.*?,\s*(.*?),\s*[A-Z]{2}\s*\b', x, flags=re.IGNORECASE).group(1).strip() if re.search(r'^.*?,\s*(.*?),\s*[A-Z]{2}\s*\b', x, flags=re.IGNORECASE) else None)
df['street_name'] = df['address'].apply(lambda x: re.search(r'^\s*(.*?),\s*[A-Z]{2}\s*\b', x, flags=re.IGNORECASE).group(1).strip() if re.search(r'^\s*(.*?),\s*[A-Z]{2}\s*\b', x, flags=re.IGNORECASE) else None)
df['province'] = df['address'].apply(lambda x: re.search(r'\b([A-Z]{2})\s*\b', x).group(1) if re.search(r'\b([A-Z]{2})\s*\b', x) else None)
df['postal_code'] = df['address'].apply(lambda x: re.search(r'\b[A-Z]\d[A-Z]\s*\d[A-Z]\d\b', x).group(0) if re.search(r'\b[A-Z]\d[A-Z]\s*\d[A-Z]\d\b', x) else None)

# %%
# Display rows where street_name column is empty
df_street_null = df[df.street_name.isna()]
df_street_null
# Out:
#              ad_id price             utility_flag  \
# 1869  1686289201.0  1000    No Utilities Included
# 1159  1686671717.0  1000  Some Utilities Included
# 2797  1685665154.0  1100    No Utilities Included
# 133   1686841609.0  1150    No Utilities Included
# 801   1686772386.0  1200    No Utilities Included
# ...            ...   ...                      ...
# 1653  1686451721.0   600    No Utilities Included
# 3029  1685489937.0   800    No Utilities Included
# 1709  1686414660.0   875    No Utilities Included
# 2875  1685604580.0   900    No Utilities Included
# 1044  1686717033.0   950    No Utilities Included
#
#                                         address  unit_type         Bedrooms  \
# 1869     2333 Rue Modigliani, Montréal, H4R 3J6  Apartment                2
# 1159     2401 Rue Park-Row E, Montréal, H4B 2H8  Apartment  Bachelor/Studio
# 2797          9169 Rue Massé, Montréal, H1R 3J1  Apartment                1
# 133          6950 Rue Birnam, Montréal, H3N 2S7  Apartment                1
# 801        6024 Rue Guérin, Terrebonne, J7M 1Z1  Apartment                1
# ...                                         ...        ...              ...
# 1653                                     J6S4K1  Apartment                1
# 3029                                    H4G 2C2  Apartment                1
# 1709          22e Avenue, L'Île-Perrot, J7V 4N7  Apartment                1
# 2875  8069 Rue A-A-Desroches, Montréal, H1L 2S3  Apartment                1
# 1044                 110 QC-335, Laval, H7G 2T3  Apartment                2
#
#       Bathrooms Utilities Included Wi-Fi and More  \
# 1869        1.0                 []             []
# 1159        1.0                 []             []
# 2797        1.0                 []             []
# 133         1.0                 []             []
# 801         1.0                 []   ['Internet']
# ...         ...                ...            ...
# 1653        1.0                 []             []
# 3029        1.0                 []             []
# 1709        1.0                 []             []
# 2875        1.0                 []             []
# 1044        1.0                 []             []
#
#                                          Appliances  ... Air Conditioning  \
# 1869                                             []  ...               No
# 1159  ['Laundry (In Building)', 'Fridge / Freezer']  ...               No
# 2797                                             []  ...               No
# 133                                              []  ...               No
# 801                       ['Laundry (In Building)']  ...               No
# ...                                             ...  ...              ...
# 1653                                             []  ...               No
# 3029                                             []  ...              Yes
# 1709                                             []  ...               No
# 2875                                             []  ...               No
# 1044                                             []  ...               No
#
#      Smoking Permitted Barrier-free Entrances and Ramps Visual Aids  \
# 1869                No                              NaN         NaN
# 1159     Outdoors only                              NaN         NaN
# 2797                No                              NaN         NaN
# 133                 No                              NaN         NaN
# 801                 No                              NaN         NaN
# ...                ...                              ...         ...
# 1653     Outdoors only                              NaN         NaN
# 3029     Outdoors only                              NaN         NaN
# 1709                No                              NaN         NaN
# 2875     Outdoors only                              NaN         NaN
# 1044                No                              NaN         NaN
#
#      Accessible Washrooms in Suite  \
# 1869                           NaN
# 1159                           NaN
# 2797                           NaN
# 133                            NaN
# 801                            NaN
# ...                            ...
# 1653                           NaN
# 3029                           NaN
# 1709                           NaN
# 2875                           NaN
# 1044                           NaN
#
#                                                  ad_url street_name  city  \
# 1869  https://www.kijiji.ca/v-apartments-condos/vill...        None  None
# 1159  https://www.kijiji.ca/v-apartments-condos/vill...        None  None
# 2797  https://www.kijiji.ca/v-apartments-condos/vill...        None  None
# 133   https://www.kijiji.ca/v-apartments-condos/vill...        None  None
# 801   https://www.kijiji.ca/v-apartments-condos/lava...        None  None
# ...                                                 ...         ...   ...
# 1653  https://www.kijiji.ca/v-apartments-condos/oues...        None  None
# 3029  https://www.kijiji.ca/v-apartments-condos/vill...        None  None
# 1709  https://www.kijiji.ca/v-apartments-condos/vill...        None  None
# 2875  https://www.kijiji.ca/v-apartments-condos/vill...        None  None
# 1044  https://www.kijiji.ca/v-apartments-condos/lava...        None  None
#
#      province postal_code
# 1869     None     H4R 3J6
# 1159     None     H4B 2H8
# 2797     None     H1R 3J1
# 133      None     H3N 2S7
# 801      None     J7M 1Z1
# ...       ...         ...
# 1653     None      J6S4K1
# 3029     None     H4G 2C2
# 1709     None     J7V 4N7
# 2875     None     H1L 2S3
# 1044       QC     H7G 2T3
#
# [65 rows x 29 columns]

# %%
# Apply the function to rows where the 'street_name' column is empty
mask = df['street_name'].isna()
df.loc[mask, ['street_name', 'city']] = df[mask]['address'].apply(split_address).tolist()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 3
#       1 # Apply the function to rows where the 'street_name' column is empty
#       2 mask = df['street_name'].isna()
# ----> 3 df.loc[mask, ['street_name', 'city']] = df[mask]['address'].apply(split_address).tolist()
#
# NameError: name 'split_address' is not defined

# %%
df.to_csv('duplicates_test_x.csv', index=False)

# %%
# Update City column where empty when city datapoint is in the street_name column
df['city'] = df.apply(lambda row: row['street_name'] if pd.isna(row['city']) and row['street_name'] is not None and (len(row['street_name'].split()) == 1 or ' ' in row['street_name']) and not any(char.isdigit() for char in row['street_name'] if row['street_name'] is not None) else row['city'], axis=1)
df['street_name'] = df.apply(lambda row: '' if row['city'] == row['street_name'] else row['street_name'], axis=1)

# %%
# Remove incorrect data point in the street_name column
df['street_name'] = df['street_name'].replace('sur rendez-vous', '')

# %%
# Standardize values to lowercase
df['street_name'] = df['street_name'].str.lower()

# %%
# Create function to remove city data from street_column
def remove_city(row):
    if row.find(',') != -1:  # Check if ',' is found in the string
        split_row = row.split(',')
        street_info = ' '.join(split_row[:-1]).strip()
        return street_info
    else:
        return row

# Remove city data from street_column
df.street_name = df['street_name'].apply(lambda row: remove_city(row))

# %%
# Review provincial column for none QC datapoints
df_prov = df[(df.province != 'QC') & (df.province.notna())]
df_prov
# Out:
#              ad_id price             utility_flag  \
# 1603  1686004920.0  1100   All Utilities Included
# 963   1657963207.0  1323   All Utilities Included
# 1579  1684054657.0  1350    No Utilities Included
# 1118  1686680687.0  1450    No Utilities Included
# 187   1672039872.0  1450  Some Utilities Included
# 69    1667831700.0  1450  Some Utilities Included
# 68    1673873130.0  1450  Some Utilities Included
# 232   1672192554.0  1550    No Utilities Included
# 956   1657963177.0  1672   All Utilities Included
# 1097  1686696191.0  1700  Some Utilities Included
# 213   1667831698.0  1750  Some Utilities Included
# 233   1675674126.0  1995    No Utilities Included
# 957   1658417704.0  2410   All Utilities Included
#
#                                            address  unit_type  \
# 1603         3777 ST-URBAIN, Montréal, QC, H2W 1T5  Apartment
# 963   95 RUE DU DORÉ JAUNE, Lachenaie, QC, J6V 0J5  Apartment
# 1579  5960 Boulevard Pie-IX, Montréal, QC, H1X 2C2  Apartment
# 1118          11209 Boulevard Pie-IX, Montréal, QC  Apartment
# 187     8500 , BOUL. VIAU, ST-LÉONARD, QC, H1R 2T7      Condo
# 69         1530 DR PENFIELD, Montreal, QC, H3G 1C1  Apartment
# 68         1530 DR PENFIELD, Montreal, QC, H3G 1C1  Apartment
# 232   5180- 5182 PH Lalonde, MONTREAL, QC, H4C 0C2  Apartment
# 956   95 RUE DU DORÉ JAUNE, Lachenaie, QC, J6V 0J5  Apartment
# 1097     CP Côte Saint-Luc, Côte Saint-Luc, QC H4W      Condo
# 213     8500 , BOUL. VIAU, ST-LÉONARD, QC, H1R 2T7      Condo
# 233   5180- 5182 PH Lalonde, MONTREAL, QC, H4C 0C2  Apartment
# 957   95 RUE DU DORÉ JAUNE, Lachenaie, QC, J6V 0J5  Apartment
#
#              Bedrooms  Bathrooms Utilities Included  \
# 1603  Bachelor/Studio        1.0                 []
# 963                 1        1.0                 []
# 1579                1        1.0                 []
# 1118                2        1.0                 []
# 187                 1        1.0                 []
# 69                  1        1.0                 []
# 68                  1        1.0                 []
# 232                 1        1.0                 []
# 956                 2        1.0                 []
# 1097                1        1.0                 []
# 213                 2        1.0                 []
# 233                 2        1.0                 []
# 957                 3        1.0                 []
#
#                   Wi-Fi and More  \
# 1603                          []
# 963   ['Cable / TV', 'Internet']
# 1579                ['Internet']
# 1118                          []
# 187                           []
# 69                            []
# 68                            []
# 232                           []
# 956   ['Cable / TV', 'Internet']
# 1097                          []
# 213                           []
# 233                           []
# 957   ['Cable / TV', 'Internet']
#
#                                              Appliances  ... Air Conditioning  \
# 1603      ['Laundry (In Building)', 'Fridge / Freezer']  ...               No
# 963   ['Laundry (In Unit)', 'Dishwasher', 'Fridge / ...  ...              Yes
# 1579      ['Laundry (In Building)', 'Fridge / Freezer']  ...              Yes
# 1118                              ['Laundry (In Unit)']  ...               No
# 187   ['Laundry (In Unit)', 'Dishwasher', 'Fridge / ...  ...              Yes
# 69    ['Laundry (In Building)', 'Dishwasher', 'Fridg...  ...              Yes
# 68    ['Laundry (In Building)', 'Dishwasher', 'Fridg...  ...               No
# 232   ['Laundry (In Unit)', 'Dishwasher', 'Fridge / ...  ...              Yes
# 956   ['Laundry (In Unit)', 'Dishwasher', 'Fridge / ...  ...              Yes
# 1097  ['Laundry (In Unit)', 'Dishwasher', 'Fridge / ...  ...              Yes
# 213   ['Laundry (In Unit)', 'Dishwasher', 'Fridge / ...  ...              Yes
# 233   ['Laundry (In Unit)', 'Dishwasher', 'Fridge / ...  ...              Yes
# 957   ['Laundry (In Unit)', 'Dishwasher', 'Fridge / ...  ...              Yes
#
#      Smoking Permitted Barrier-free Entrances and Ramps Visual Aids  \
# 1603                No                              NaN         NaN
# 963                 No                              NaN         NaN
# 1579                No                              NaN         NaN
# 1118                No                              NaN         NaN
# 187                 No                               No          No
# 69                  No                              Yes          No
# 68                  No                              Yes          No
# 232                 No                              NaN         NaN
# 956                 No                              NaN         NaN
# 1097     Outdoors only                              Yes          No
# 213                 No                               No          No
# 233                 No                              NaN         NaN
# 957                 No                              NaN         NaN
#
#      Accessible Washrooms in Suite  \
# 1603                           NaN
# 963                            NaN
# 1579                           NaN
# 1118                           NaN
# 187                             No
# 69                              No
# 68                              No
# 232                            NaN
# 956                            NaN
# 1097                            No
# 213                             No
# 233                            NaN
# 957                            NaN
#
#                                                  ad_url  \
# 1603  https://www.kijiji.ca/v-apartments-condos/vill...
# 963   https://www.kijiji.ca/v-apartments-condos/lava...
# 1579  https://www.kijiji.ca/v-apartments-condos/vill...
# 1118  https://www.kijiji.ca/v-apartments-condos/vill...
# 187   https://www.kijiji.ca/v-apartments-condos/vill...
# 69    https://www.kijiji.ca/v-apartments-condos/vill...
# 68    https://www.kijiji.ca/v-apartments-condos/vill...
# 232   https://www.kijiji.ca/v-apartments-condos/vill...
# 956   https://www.kijiji.ca/v-apartments-condos/lava...
# 1097  https://www.kijiji.ca/v-apartments-condos/vill...
# 213   https://www.kijiji.ca/v-apartments-condos/vill...
# 233   https://www.kijiji.ca/v-apartments-condos/vill...
# 957   https://www.kijiji.ca/v-apartments-condos/lava...
#
#                  street_name            city province postal_code
# 1603          3777 ST-URBAIN        Montréal       ST     H2W 1T5
# 963     95 RUE DU DORÉ JAUNE       Lachenaie       DU     J6V 0J5
# 1579   5960 Boulevard Pie-IX        Montréal       IX     H1X 2C2
# 1118  11209 Boulevard Pie-IX        Montréal       IX        None
# 187                     8500      BOUL. VIAU       ST     H1R 2T7
# 69          1530 DR PENFIELD        Montreal       DR     H3G 1C1
# 68          1530 DR PENFIELD        Montreal       DR     H3G 1C1
# 232    5180- 5182 PH Lalonde        MONTREAL       PH     H4C 0C2
# 956     95 RUE DU DORÉ JAUNE       Lachenaie       DU     J6V 0J5
# 1097       CP Côte Saint-Luc  Côte Saint-Luc       CP        None
# 213                     8500      BOUL. VIAU       ST     H1R 2T7
# 233    5180- 5182 PH Lalonde        MONTREAL       PH     H4C 0C2
# 957     95 RUE DU DORÉ JAUNE       Lachenaie       DU     J6V 0J5
#
# [13 rows x 29 columns]

# %%
# Delete rows where data is for rental units in Ontario
df = df[df['province'] != 'ON']

# %%
# Convert all provincial datapoints to QC

# %%
# Remove postal code info from street_name column

# Define a regular expression pattern to match the specified format
pattern = r'^[A-Z]\d+[A-Z]'

# Function to check if the street_name matches the pattern
def delete_street_name(row):
    if re.match(pattern, row['street_name']):
        return ''  # Replace the street_name with an empty string if it matches the pattern
    else:
        return row['street_name']  # Keep the street_name if it doesn't match the pattern

# Apply the function to the 'street_name' column
df['street_name'] = df.apply(delete_street_name, axis=1)

# %%
# Remove spacing within within the postal_code column
df['postal_code'] = df['postal_code'].str.replace(' ', '')

# %%
print(df.postal_code)
# Out:
# 1090    H1A1V9
# 2002    J2W2G6
# 1904    H4E3W3
# 1869    H4R3J6
# 1827    H2K4B2
#          ...
# 1311    H4V2E7
# 1008    H3S1J1
# 1379    J5X3Z8
# 138       None
# 2559    J4Z3J8
# Name: postal_code, Length: 2664, dtype: object

# %%
# Define the get_geolocation function
def get_geolocation(postal_code):
    api_key = 'AIzaSyDZD9S6k5pQp4Y9WwoYcaUlxtrDpFZ98Fc'
    base_url = 'https://maps.googleapis.com/maps/api/geocode/json'

    # Prepare the request parameters
    params = {'address': f'{postal_code}, Canada', 'key': api_key}

    # Send the request to the Google Maps Geocoding API
    response = requests.get(base_url, params=params)
    data = response.json()

    # Extract latitude and longitude from the response
    if data['status'] == 'OK' and data.get('results'):
        result = data['results'][0]
        location = result['geometry']['location']
        latitude = location['lat']
        longitude = location['lng']
        return latitude, longitude
    else:
        return None, None

# %%
# Assuming df is your DataFrame
df['latitude'], df['longitude'] = zip(*df['postal_code'].apply(get_geolocation))

# Display the DataFrame
print(df)
# Out:
#              ad_id price             utility_flag  \
# 1090  1686673911.0  1000    No Utilities Included
# 2002  1686209958.0  1000    No Utilities Included
# 1904  1686271403.0  1000    No Utilities Included
# 1869  1686289201.0  1000    No Utilities Included
# 1827  1686326330.0  1000    No Utilities Included
# ...            ...   ...                      ...
# 1311  1686627721.0   995    No Utilities Included
# 1008  1686207920.0   995  Some Utilities Included
# 1379  1686599048.0   995  Some Utilities Included
# 138   1686840144.0   995    No Utilities Included
# 2559  1685900256.0   999    No Utilities Included
#
#                                               address  unit_type  \
# 1090                  Pointe-aux-Trembles, QC H1A 1V9  Apartment
# 2002  775 Boul St-Luc, St-Jean-sur-Richelieu, J2W 2G6  Apartment
# 1904                             Montréal, QC H4E 3W3  Apartment
# 1869           2333 Rue Modigliani, Montréal, H4R 3J6  Apartment
# 1827                             Montréal, QC H2K 4B2  Apartment
# ...                                               ...        ...
# 1311                             Montreal, QC H4V 2E7  Apartment
# 1008              3370,  Goyer, Montréal, QC, H3S 1J1  Apartment
# 1379                          L'Épiphanie, QC J5X 3Z8  Apartment
# 138                          Sainte-Catherine, QC J5C  Apartment
# 2559   103A-6240 Av. Bienville, Brossard, QC, J4Z 3J8  Apartment
#
#              Bedrooms  Bathrooms Utilities Included Wi-Fi and More  \
# 1090                2        1.0                 []             []
# 2002                1        1.5                 []             []
# 1904  Bachelor/Studio        1.0                 []             []
# 1869                2        1.0                 []             []
# 1827                3        1.0                 []             []
# ...               ...        ...                ...            ...
# 1311          1 + Den        1.0                 []             []
# 1008  Bachelor/Studio        1.0                 []   ['Internet']
# 1379                1        1.0                 []             []
# 138                 2        1.0                 []             []
# 2559                1        1.0                 []             []
#
#                                          Appliances  ...  \
# 1090                                             []  ...
# 2002                                             []  ...
# 1904      ['Laundry (In Unit)', 'Fridge / Freezer']  ...
# 1869                                             []  ...
# 1827      ['Laundry (In Unit)', 'Fridge / Freezer']  ...
# ...                                             ...  ...
# 1311  ['Laundry (In Building)', 'Fridge / Freezer']  ...
# 1008                      ['Laundry (In Building)']  ...
# 1379                                             []  ...
# 138                           ['Laundry (In Unit)']  ...
# 2559                      ['Laundry (In Building)']  ...
#
#      Barrier-free Entrances and Ramps Visual Aids  \
# 1090                              NaN         NaN
# 2002                              NaN         NaN
# 1904                              NaN         NaN
# 1869                              NaN         NaN
# 1827                              NaN         NaN
# ...                               ...         ...
# 1311                              NaN         NaN
# 1008                              NaN         NaN
# 1379                              NaN         NaN
# 138                               NaN         NaN
# 2559                              NaN         NaN
#
#      Accessible Washrooms in Suite  \
# 1090                           NaN
# 2002                           NaN
# 1904                           NaN
# 1869                           NaN
# 1827                           NaN
# ...                            ...
# 1311                           NaN
# 1008                           NaN
# 1379                           NaN
# 138                            NaN
# 2559                           NaN
#
#                                                  ad_url  \
# 1090  https://www.kijiji.ca/v-apartments-condos/vill...
# 2002  https://www.kijiji.ca/v-apartments-condos/long...
# 1904  https://www.kijiji.ca/v-apartments-condos/vill...
# 1869  https://www.kijiji.ca/v-apartments-condos/vill...
# 1827  https://www.kijiji.ca/v-apartments-condos/vill...
# ...                                                 ...
# 1311  https://www.kijiji.ca/v-apartments-condos/vill...
# 1008  https://www.kijiji.ca/v-apartments-condos/vill...
# 1379  https://www.kijiji.ca/v-apartments-condos/lava...
# 138   https://www.kijiji.ca/v-apartments-condos/long...
# 2559  https://www.kijiji.ca/v-apartments-condos/long...
#
#                   street_name                 city province postal_code  \
# 1090                           Pointe-aux-Trembles       QC      H1A1V9
# 2002          775 boul st-luc                 None     None      J2W2G6
# 1904                                      Montréal       QC      H4E3W3
# 1869                                          None     None      H4R3J6
# 1827                                      Montréal       QC      H2K4B2
# ...                       ...                  ...      ...         ...
# 1311                                      Montreal       QC      H4V2E7
# 1008             3370   goyer      Goyer, Montréal       QC      H3S1J1
# 1379                                   L'Épiphanie       QC      J5X3Z8
# 138                               Sainte-Catherine       QC        None
# 2559  103a-6240 av. bienville             Brossard       QC      J4Z3J8
#
#        Latitude   Longitude
# 1090  45.674941  -73.493341
# 2002  45.360106  -73.335383
# 1904  45.462249  -73.587671
# 1869  45.509205  -73.716202
# 1827  45.527989  -73.560835
# ...         ...         ...
# 1311  45.463182  -73.644376
# 1008  45.504643  -73.634972
# 1379  45.850173  -73.494066
# 138   56.130366 -106.346771
# 2559  45.468995  -73.452945
#
# [2664 rows x 31 columns]

# %%
from geopy.geocoders import Nominatim

from retry import retry

@retry(tries=3, delay=2, backoff=2)
def get_neighborhood_name(latitude, longitude):
    geolocator = Nominatim(user_agent="neighborhood_finder")
    location = geolocator.reverse((latitude, longitude))
    address = location.raw.get('address')
    neighborhood = address.get('suburb', '')
    if not neighborhood:
        city = address.get('city', '')
        return city
    return neighborhood

# Assuming df is your DataFrame
df['neighborhood'] = df.apply(lambda row: get_neighborhood_name(row['Latitude'], row['Longitude']), axis=1)

print(df)
# Out:
#              ad_id price             utility_flag  \
# 1090  1686673911.0  1000    No Utilities Included
# 2002  1686209958.0  1000    No Utilities Included
# 1904  1686271403.0  1000    No Utilities Included
# 1869  1686289201.0  1000    No Utilities Included
# 1827  1686326330.0  1000    No Utilities Included
# ...            ...   ...                      ...
# 1311  1686627721.0   995    No Utilities Included
# 1008  1686207920.0   995  Some Utilities Included
# 1379  1686599048.0   995  Some Utilities Included
# 138   1686840144.0   995    No Utilities Included
# 2559  1685900256.0   999    No Utilities Included
#
#                                               address  unit_type  \
# 1090                  Pointe-aux-Trembles, QC H1A 1V9  Apartment
# 2002  775 Boul St-Luc, St-Jean-sur-Richelieu, J2W 2G6  Apartment
# 1904                             Montréal, QC H4E 3W3  Apartment
# 1869           2333 Rue Modigliani, Montréal, H4R 3J6  Apartment
# 1827                             Montréal, QC H2K 4B2  Apartment
# ...                                               ...        ...
# 1311                             Montreal, QC H4V 2E7  Apartment
# 1008              3370,  Goyer, Montréal, QC, H3S 1J1  Apartment
# 1379                          L'Épiphanie, QC J5X 3Z8  Apartment
# 138                          Sainte-Catherine, QC J5C  Apartment
# 2559   103A-6240 Av. Bienville, Brossard, QC, J4Z 3J8  Apartment
#
#              Bedrooms  Bathrooms Utilities Included Wi-Fi and More  \
# 1090                2        1.0                 []             []
# 2002                1        1.5                 []             []
# 1904  Bachelor/Studio        1.0                 []             []
# 1869                2        1.0                 []             []
# 1827                3        1.0                 []             []
# ...               ...        ...                ...            ...
# 1311          1 + Den        1.0                 []             []
# 1008  Bachelor/Studio        1.0                 []   ['Internet']
# 1379                1        1.0                 []             []
# 138                 2        1.0                 []             []
# 2559                1        1.0                 []             []
#
#                                          Appliances  ... Visual Aids  \
# 1090                                             []  ...         NaN
# 2002                                             []  ...         NaN
# 1904      ['Laundry (In Unit)', 'Fridge / Freezer']  ...         NaN
# 1869                                             []  ...         NaN
# 1827      ['Laundry (In Unit)', 'Fridge / Freezer']  ...         NaN
# ...                                             ...  ...         ...
# 1311  ['Laundry (In Building)', 'Fridge / Freezer']  ...         NaN
# 1008                      ['Laundry (In Building)']  ...         NaN
# 1379                                             []  ...         NaN
# 138                           ['Laundry (In Unit)']  ...         NaN
# 2559                      ['Laundry (In Building)']  ...         NaN
#
#      Accessible Washrooms in Suite  \
# 1090                           NaN
# 2002                           NaN
# 1904                           NaN
# 1869                           NaN
# 1827                           NaN
# ...                            ...
# 1311                           NaN
# 1008                           NaN
# 1379                           NaN
# 138                            NaN
# 2559                           NaN
#
#                                                  ad_url  \
# 1090  https://www.kijiji.ca/v-apartments-condos/vill...
# 2002  https://www.kijiji.ca/v-apartments-condos/long...
# 1904  https://www.kijiji.ca/v-apartments-condos/vill...
# 1869  https://www.kijiji.ca/v-apartments-condos/vill...
# 1827  https://www.kijiji.ca/v-apartments-condos/vill...
# ...                                                 ...
# 1311  https://www.kijiji.ca/v-apartments-condos/vill...
# 1008  https://www.kijiji.ca/v-apartments-condos/vill...
# 1379  https://www.kijiji.ca/v-apartments-condos/lava...
# 138   https://www.kijiji.ca/v-apartments-condos/long...
# 2559  https://www.kijiji.ca/v-apartments-condos/long...
#
#                   street_name                 city province postal_code  \
# 1090                           Pointe-aux-Trembles       QC      H1A1V9
# 2002          775 boul st-luc                 None     None      J2W2G6
# 1904                                      Montréal       QC      H4E3W3
# 1869                                          None     None      H4R3J6
# 1827                                      Montréal       QC      H2K4B2
# ...                       ...                  ...      ...         ...
# 1311                                      Montreal       QC      H4V2E7
# 1008             3370   goyer      Goyer, Montréal       QC      H3S1J1
# 1379                                   L'Épiphanie       QC      J5X3Z8
# 138                               Sainte-Catherine       QC        None
# 2559  103a-6240 av. bienville             Brossard       QC      J4Z3J8
#
#        Latitude   Longitude                              neighborhood
# 1090  45.674941  -73.493341  Rivière-des-Prairies–Pointe-aux-Trembles
# 2002  45.360106  -73.335383                                 Saint-Luc
# 1904  45.462249  -73.587671                              Le Sud-Ouest
# 1869  45.509205  -73.716202                             Saint-Laurent
# 1827  45.527989  -73.560835                               Ville-Marie
# ...         ...         ...                                       ...
# 1311  45.463182  -73.644376       Côte-des-Neiges–Notre-Dame-de-Grâce
# 1008  45.504643  -73.634972       Côte-des-Neiges–Notre-Dame-de-Grâce
# 1379  45.850173  -73.494066
# 138   56.130366 -106.346771               Unorganized Division No. 18
# 2559  45.468995  -73.452945
#
# [2664 rows x 32 columns]

# %%
# Export DataFrame to CSV file
df.to_csv('duplicates_test_y.csv', index=False)

# %%
from geopy.geocoders import Nominatim

def get_neighborhood_name(latitude, longitude):
    geolocator = Nominatim(user_agent="neighborhood_finder")
    location = geolocator.reverse((latitude, longitude))
    print(location.raw)
    address = location.raw.get('address')
    neighborhood = address.get('suburb', '')
    city = address.get('city', '')
    print(neighborhood)
    return neighborhood, city

latitude = 45.7028448  # Example latitude
longitude = -74.0787847  # Example longitude
neighborhood_name = get_neighborhood_name(latitude, longitude)
print("Neighborhood:", neighborhood_name)
#print("City:", city)
# Out:
# {'place_id': 22691077, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 492499674, 'lat': '45.70301890127223', 'lon': '-74.0788496025609', 'class': 'highway', 'type': 'residential', 'place_rank': 26, 'importance': 0.10000999999999993, 'addresstype': 'road', 'name': 'Rue du Beaujolais', 'display_name': 'Rue du Beaujolais, Mirabel, Laurentides, Québec, J7N 0M2, Canada', 'address': {'road': 'Rue du Beaujolais', 'city': 'Mirabel', 'region': 'Laurentides', 'state': 'Québec', 'ISO3166-2-lvl4': 'CA-QC', 'postcode': 'J7N 0M2', 'country': 'Canada', 'country_code': 'ca'}, 'boundingbox': ['45.7020624', '45.7051773', '-74.0794597', '-74.0747085']}
#
# Neighborhood: ('', 'Mirabel')

# %%
df['neighborhood'] = zip(*df['postal_code']

# %%
import requests

def get_neighborhood_name(latitude, longitude):
    # Replace 'YOUR_API_KEY' with your actual Google Maps API key
    api_key = 'AIzaSyDZD9S6k5pQp4Y9WwoYcaUlxtrDpFZ98Fc'
    base_url = 'https://maps.googleapis.com/maps/api/geocode/json'

    # Prepare the request parameters
    params = {
        'latlng': f'{latitude},{longitude}',
        'key': api_key
    }

    # Send the request to the Google Maps Geocoding API
    response = requests.get(base_url, params=params)
    data = response.json()

    # Extract neighborhood name from the response
    if data['status'] == 'OK' and data.get('results'):
        address_components = data['results'][0]['address_components']
        neighborhood_name = next((component['long_name'] for component in address_components if 'neighborhood' in component['types']), None)
        return neighborhood_name
    else:
        return None

# Example usage
latitude = 45.5017  # Example latitude (e.g., Montreal)
longitude = -73.5673  # Example longitude (e.g., Montreal)
neighborhood_name = get_neighborhood_name(latitude, longitude)
if neighborhood_name:
    print(f'Neighborhood: {neighborhood_name}')
else:
    print('Neighborhood name not found for the provided geolocation.')
-74.0060
# Out:
# Neighborhood name not found for the provided geolocation.

# %%
print(neighborhood_name)

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2668 entries, 1090 to 2559
# Data columns (total 25 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   ad_id                             2668 non-null   object
#  1   price                             2668 non-null   object
#  2   utility_flag                      2666 non-null   object
#  3   address                           2668 non-null   object
#  4   unit_type                         2666 non-null   object
#  5   Bedrooms                          2666 non-null   object
#  6   Bathrooms                         2666 non-null   float64
#  7   Utilities Included                2666 non-null   object
#  8   Wi-Fi and More                    2666 non-null   object
#  9   Appliances                        2666 non-null   object
#  10  Personal Outdoor Space            2666 non-null   object
#  11  Amenities                         2384 non-null   object
#  12  Elevator Accessibility Features   325 non-null    object
#  13  Parking Included                  2666 non-null   object
#  14  Agreement Type                    2666 non-null   object
#  15  Move-In Date                      2232 non-null   object
#  16  Pet Friendly                      2666 non-null   object
#  17  Size (sqft)                       2666 non-null   object
#  18  Furnished                         2666 non-null   object
#  19  Air Conditioning                  2666 non-null   object
#  20  Smoking Permitted                 2666 non-null   object
#  21  Barrier-free Entrances and Ramps  365 non-null    object
#  22  Visual Aids                       365 non-null    object
#  23  Accessible Washrooms in Suite     365 non-null    object
#  24  ad_url                            2668 non-null   object
# dtypes: float64(1), object(24)
# memory usage: 541.9+ KB
# None

# %%
# Remove rows outside of the greater montreal area

# %%
# Convert Bachelor/Studio text to 0

# %%
# Add a den flag and the word Den in the bathroom

# %% [markdown]
# After reviewing various instances of duplicates. It seems that certain users are posting extremely similar ads with slight differences.
# For example, Ad ID 1505842847 and 1505842805 have all the same characteristics (excluding ad id) but description section is in different languages (French and English)

# %% [markdown]
# # Exploring Kijiji Data
